# %%
import pandas as pd
GIFT_AMOUNT = pd.read_excel(r'C:\Users\sithara\Desktop\Philanthrophy\File\Management data_2.xlsx')
df = pd.DataFrame(GIFT_AMOUNT,columns=['GIFT_AMOUNT_2018_NEW','GIFT_AMOUNT_2017_NEW','LAST_GIFT_AMOUNT','ZIPCODE_NEW'])

# %%
i=0
elem =[]
elem1 = []
elem2 = []
GIFT_AMOUNT['ZIPCODE_NEW']=GIFT_AMOUNT.ZIPCODE_NEW.astype(int)
elem = GIFT_AMOUNT['ZIPCODE_NEW'].tolist()
elem = list(map(int, elem))

# %%
i=0
elem =[]
elem1 = []
elem2 = []
GIFT_AMOUNT['NO_EVENTS_2018_NEW']=GIFT_AMOUNT.NO_EVENTS_2018_NEW.astype(int)
GIFT_AMOUNT['NO_EVENTS_2017_NEW']=GIFT_AMOUNT.NO_EVENTS_2017_NEW.astype(int)
GIFT_AMOUNT['NO_EVENTS_2016_NEW']=GIFT_AMOUNT.NO_EVENTS_2016_NEW.astype(int)
GIFT_AMOUNT['NO_EVENTS_2015_NEW']=GIFT_AMOUNT.NO_EVENTS_2015_NEW.astype(int)
elem = GIFT_AMOUNT['NO_EVENTS_2018_NEW'].tolist()
elem1 = GIFT_AMOUNT['NO_EVENTS_2017_NEW'].tolist()
elem2 = GIFT_AMOUNT['NO_EVENTS_2016_NEW'].tolist()
elem3 = GIFT_AMOUNT['NO_EVENTS_2015_NEW'].tolist()
elem1 = list(map(int, elem1))
elem = list(map(int, elem))
elem2 = list(map(int, elem2))
elem3 = list(map(int, elem3))
#print(GIFT_AMOUNT.dtypes)
for i in range(0,len(elem)):#GIFT_AMOUNT['NO_EVENTS_2018_NEW']):
    if elem[i]>2:
        elem[i]=3
i=0
for i in range(0,len(elem1)):#GIFT_AMOUNT['NO_EVENTS_2017_NEW']):
    if elem1[i]>2:
        elem1[i]=3
i=0
for i in range(0,len(elem2)):#GIFT_AMOUNT['NO_EVENTS_2016_NEW']):
    if elem2[i]>2:
        elem2[i]=3
i=0
for i in range(0,len(elem3)):#GIFT_AMOUNT['NO_EVENTS_2015_NEW']):
    if elem3[i]>2:
        elem3[i]=3
#print(elem1)
        #list.append(elem)

# %%
import statsmodels.formula.api as smf
lm = lm = smf.ols('GIFT_AMOUNT_2018_NEW ~ NO_EVENTS_2018_NEW+GIFT_AMOUNT_2017_NEW+GIFT_AMOUNT_2016_NEW+GIFT_AMOUNT_2015_NEW+NO_EVENTS_2016_NEW+NO_EVENTS_2017_NEW', data = GIFT_AMOUNT).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     GIFT_AMOUNT_2018_NEW   R-squared:                       0.943
# Model:                              OLS   Adj. R-squared:                  0.943
# Method:                   Least Squares   F-statistic:                 1.074e+05
# Date:                  Wed, 19 Jun 2019   Prob (F-statistic):               0.00
# Time:                          03:44:44   Log-Likelihood:            -3.5869e+05
# No. Observations:                 38814   AIC:                         7.174e+05
# Df Residuals:                     38807   BIC:                         7.175e+05
# Df Model:                             6
# Covariance Type:              nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                5.9577     12.866      0.463      0.643     -19.260      31.176
# NO_EVENTS_2018_NEW     -31.2403     29.844     -1.047      0.295     -89.735      27.255
# GIFT_AMOUNT_2017_NEW    -0.1204      0.025     -4.784      0.000      -0.170      -0.071
# GIFT_AMOUNT_2016_NEW     1.8582      0.031     60.132      0.000       1.798       1.919
# GIFT_AMOUNT_2015_NEW     0.2261      0.028      8.168      0.000       0.172       0.280
# NO_EVENTS_2016_NEW    -202.0171     34.076     -5.928      0.000    -268.807    -135.227
# NO_EVENTS_2017_NEW      78.3890     34.557      2.268      0.023      10.657     146.122
# ==============================================================================
# Omnibus:                   137886.601   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      83461753617.554
# Skew:                          70.950   Prob(JB):                         0.00
# Kurtosis:                    7185.414   Cond. No.                     2.97e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels.formula.api as smf
lm = lm = smf.ols('GIFT_AMOUNT_2018_NEW ~ GIFT_AMOUNT_2017_NEW+GIFT_AMOUNT_2016_NEW+GIFT_AMOUNT_2015_NEW+C(elem)', data = GIFT_AMOUNT).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     GIFT_AMOUNT_2018_NEW   R-squared:                       0.943
# Model:                              OLS   Adj. R-squared:                  0.943
# Method:                   Least Squares   F-statistic:                 1.074e+05
# Date:                  Tue, 18 Jun 2019   Prob (F-statistic):               0.00
# Time:                          13:23:14   Log-Likelihood:            -3.5869e+05
# No. Observations:                 38814   AIC:                         7.174e+05
# Df Residuals:                     38807   BIC:                         7.174e+05
# Df Model:                             6
# Covariance Type:              nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                3.9778     12.962      0.307      0.759     -21.429      29.384
# C(elem)[T.1]          -227.9542     73.853     -3.087      0.002    -372.707     -83.201
# C(elem)[T.2]           682.1990    155.667      4.382      0.000     377.087     987.311
# C(elem)[T.3]          -794.6142    144.261     -5.508      0.000   -1077.370    -511.858
# GIFT_AMOUNT_2017_NEW    -0.1141      0.025     -4.532      0.000      -0.163      -0.065
# GIFT_AMOUNT_2016_NEW     1.8480      0.031     59.776      0.000       1.787       1.909
# GIFT_AMOUNT_2015_NEW     0.2303      0.028      8.319      0.000       0.176       0.285
# ==============================================================================
# Omnibus:                   137861.551   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      83537931886.889
# Skew:                          70.909   Prob(JB):                         0.00
# Kurtosis:                    7188.694   Cond. No.                     1.10e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels.formula.api as smf
lm = lm = smf.ols('GIFT_AMOUNT_2018_NEW ~ GIFT_AMOUNT_2017_NEW+LAST_GIFT_AMOUNT+C(elem)', data = GIFT_AMOUNT).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     GIFT_AMOUNT_2018_NEW   R-squared:                       0.953
# Model:                              OLS   Adj. R-squared:                  0.953
# Method:                   Least Squares   F-statistic:                 6.587e+04
# Date:                  Wed, 22 May 2019   Prob (F-statistic):               0.00
# Time:                          14:50:59   Log-Likelihood:            -1.2595e+05
# No. Observations:                 12993   AIC:                         2.519e+05
# Df Residuals:                     12988   BIC:                         2.519e+05
# Df Model:                             4
# Covariance Type:              nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             -429.7249     91.833     -4.679      0.000    -609.730    -249.719
# C(elem)[T.11023]      -650.2581    363.112     -1.791      0.073   -1362.012      61.495
# C(elem)[T.11111]       292.2631     99.117      2.949      0.003      97.978     486.548
# GIFT_AMOUNT_2017_NEW     1.9265      0.004    501.408      0.000       1.919       1.934
# LAST_GIFT_AMOUNT         0.6881      0.009     74.978      0.000       0.670       0.706
# ==============================================================================
# Omnibus:                    18772.967   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1073200893.892
# Skew:                          -6.976   Prob(JB):                         0.00
# Kurtosis:                    1410.894   Cond. No.                     9.56e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
